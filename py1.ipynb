# %%
print ("hello am testing")
# Out:
# hello am testing

# %% [markdown]
# # Assignment: Exploring Pandas in Python

# %%
'''Write the command to install the pandas library using pip.
Install numpy library.'''

'''Part 1: Installation and Setup
Install pandas library.'''

pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.0 kB 660.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 660.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 147.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 871.5 kB/s eta 0:00:14
#    ---------------------------------------- 0.1/11.5 MB 901.1 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.5 MB 700.2 kB/s eta 0:00:17
#     --------------------------------------- 0.3/11.5 MB 787.7 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/11.5 MB 1.0 MB/s eta 0:00:11
# ...

# %%
'''Write the command to install the numpy library using pip.
Import Libraries.'''
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/164.2 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/164.2 kB ? eta -:--:--
#      -------------------- ---------------- 92.2/164.2 kB 403.5 kB/s eta 0:00:01
#      -----------------------------------  163.8/164.2 kB 492.3 kB/s eta 0:00:01
#      -----------------------------------  163.8/164.2 kB 492.3 kB/s eta 0:00:01
#      -----------------------------------  163.8/164.2 kB 492.3 kB/s eta 0:00:01
#      ------------------------------------ 164.2/164.2 kB 179.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB 2.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/8.0 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/8.0 MB 1.6 MB/s eta 0:00:05
#    --- ------------------------------------ 0.6/8.0 MB 1.2 MB/s eta 0:00:07
# ...

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 445.2 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 375.8 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 375.8 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 170.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 1.7 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/10.9 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.9 MB 1.0 MB/s eta 0:00:11
#    - -------------------------------------- 0.3/10.9 MB 886.2 kB/s eta 0:00:13
#    - -------------------------------------- 0.5/10.9 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/10.9 MB 1.4 MB/s eta 0:00:08
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.6 MB 262.6 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/8.6 MB 262.6 kB/s eta 0:00:33
#    ---------------------------------------- 0.0/8.6 MB 196.9 kB/s eta 0:00:44
#    ---------------------------------------- 0.1/8.6 MB 234.9 kB/s eta 0:00:37
#    ---------------------------------------- 0.1/8.6 MB 270.5 kB/s eta 0:00:32
#     --------------------------------------- 0.1/8.6 MB 252.2 kB/s eta 0:00:34
#     --------------------------------------- 0.1/8.6 MB 248.7 kB/s eta 0:00:35
#     --------------------------------------- 0.1/8.6 MB 248.7 kB/s eta 0:00:35
#     --------------------------------------- 0.1/8.6 MB 258.5 kB/s eta 0:00:33
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 640.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 30.7/294.9 kB 640.0 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.9 kB 391.3 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 435.7 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/294.9 kB 399.4 kB/s eta 0:00:01
#    ------------------- ------------------ 153.6/294.9 kB 458.0 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.9 kB 436.8 kB/s eta 0:00:01
#    ----------------------------------- -- 276.5/294.9 kB 548.9 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 570.1 kB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 492.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytorch
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pytorch (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Bilal Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "c:\Users\Bilal Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\Bilal Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
# ...

# %%
'''Write the code to import the pandas library as pd.
Write the code to import the numpy library as np.'''

import pandas as pd 
import numpy as np

# %% [markdown]
# ## Part 2: Basic Data Structures

# %%
# Create a Series.
# Create a pandas Series with the values [1, 3, 5, np.nan, 6, 8].
df= pd.Series([1,3,5,np.nan, 6,8])
print(df)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Generate a Date Range.
# Generate a date range starting from "2024-01-01" with a period of 6 days.
dates=pd.date_range("20240101", periods=6)
print(dates)
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
'''Create a DataFrame with Random Numbers.
Create a pandas DataFrame with 6 rows and 4 columns of random numbers, 
indexed by the date range generated in question 5, and columns named A, B, C, D.'''
df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)
# Out:
#                    A         B         C         D
# 2024-01-01  0.464644  1.240169  0.789531  0.573035
# 2024-01-02  1.667003  1.036514  0.190917  0.126669
# 2024-01-03 -0.616373  0.630375 -1.296451 -1.996982
# 2024-01-04  1.198207  0.238779 -0.614135 -0.728441
# 2024-01-05 -0.640837  0.332348 -0.685820  0.079604
# 2024-01-06 -1.182527 -1.081328 -1.075255  1.081190

# %%
# Create a DataFrame with Different Data Types.
# Create a pandas DataFrame with the following data:
'''A: 1.0
B: Timestamp "2013-01-02"
C: Series of 1 with index from 0 to 3, dtype "float32"
D: Array of [3, 3, 3, 3], dtype "int32"
E: Categorical ["test", "train", "test", "train"]
F: "foo"
Display Data Types.
Display the data types of each column in the DataFrame created in question 7.'''


df2 = pd.DataFrame(
    {
     "A":1.0,
     "B": pd.Timestamp("20240101"),
     "C": pd.Series(1, index=(range(4))),
     "D": np.array([3]*4, dtype="int32"),
     "E": pd.Categorical(["test", "train", "test", "train"]),
     "F": "foo",
    }
)
df2.head()
df2.info()
df2.tail(2)
df2.index
df2.columns
df2.describe()
df2.T
print(df)
print (df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      int64
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[s](1), float64(1), int32(1), int64(1), object(1)
# memory usage: 404.0+ bytes
#                    A         B         C         D
# 2024-01-01  0.464644  1.240169  0.789531  0.573035
# 2024-01-02  1.667003  1.036514  0.190917  0.126669
# 2024-01-03 -0.616373  0.630375 -1.296451 -1.996982
# 2024-01-04  1.198207  0.238779 -0.614135 -0.728441
# 2024-01-05 -0.640837  0.332348 -0.685820  0.079604
# 2024-01-06 -1.182527 -1.081328 -1.075255  1.081190
#      A          B  C  D      E    F
# 0  1.0 2024-01-01  1  3   test  foo
# ...

# %% [markdown]
# ## Part 3: Viewing Data

# %%
'''View the First Few Rows.
Show the first 5 rows of the DataFrame created in question 6.
View the Last Few Rows.
Show the last 3 rows of the DataFrame created in question 6.'''

df2.loc[:, ["A", "B"]]
# Out:
#      A          B
# 0  1.0 2024-01-01
# 1  1.0 2024-01-01
# 2  1.0 2024-01-01
# 3  1.0 2024-01-01

# %%
df2 = pd.DataFrame(
    {
     "A":1.0,
     "B": pd.Timestamp("20240101"),
     "C": pd.Series(1, index=(range(4))),
     "D": np.array([3]*4, dtype="int32"),
     "E": pd.Categorical(["test", "train", "test", "train"]),
     "F": "foo",
    }
)
df2.head()
df2.info()
df2.tail(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      int64
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[s](1), float64(1), int32(1), int64(1), object(1)
# memory usage: 404.0+ bytes
#      A          B  C  D      E    F
# 2  1.0 2024-01-01  1  3   test  foo
# 3  1.0 2024-01-01  1  3  train  foo

# %%
# Display Index and Columns.
# Display the index of the DataFrame created in question 7.
# Display the column names of the DataFrame created in question 6.


df2 = pd.DataFrame(
    {
     "A":1.0,
     "B": pd.Timestamp("20240101"),
     "C": pd.Series(1, index=(range(4))),
     "D": np.array([3]*4, dtype="int32"),
     "E": pd.Categorical(["test", "train", "test", "train"]),
     "F": "foo",
    }
)
df2.index
df2.columns
df2.describe()
print(df2.index)
print(df2.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
# Convert DataFrames to Numpy Arrays.
# Convert the DataFrame created in question 6 to a numpy array.
# Convert the DataFrame created in question 7 to a numpy array.

df2 = pd.DataFrame(
    {
    
     "A":1.0,
     "B": pd.Timestamp("20240101"),
     "C": pd.Series(1, index=(range(4))),
     "D": np.array([3]*4, dtype="int32"),
     "E": pd.Categorical(["test", "train", "test", "train"]),
     "F": "foo",
    }
)

df3=df2.to_numpy
print(df3)
# Out:
# <bound method DataFrame.to_numpy of      A          B  C  D      E    F
# 0  1.0 2024-01-01  1  3   test  foo
# 1  1.0 2024-01-01  1  3  train  foo
# 2  1.0 2024-01-01  1  3   test  foo
# 3  1.0 2024-01-01  1  3  train  foo>

# %%
'''Summary Statistics.
Provide a summary description of the DataFrame created in question 6.'''
df2 = pd.DataFrame(
    {
    
     "A":1.0,
     "B": pd.Timestamp("20240101"),
     "C": pd.Series(1, index=(range(4))),
     "D": np.array([3]*4, dtype="int32"),
     "E": pd.Categorical(["test", "train", "test", "train"]),
     "F": "foo",
    }
)

print(df2.describe())
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2024-01-01 00:00:00  1.0  3.0
# min    1.0  2024-01-01 00:00:00  1.0  3.0
# 25%    1.0  2024-01-01 00:00:00  1.0  3.0
# 50%    1.0  2024-01-01 00:00:00  1.0  3.0
# 75%    1.0  2024-01-01 00:00:00  1.0  3.0
# max    1.0  2024-01-01 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# Transpose DataFrame.
# Transpose the DataFrame created in question 6.
df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)
# For Transpose
df0= df.T
print(df0)
# Out:
#                    A         B         C         D
# 2024-01-01 -0.754981  0.598583  1.168575  0.191978
# 2024-01-02  0.165291  1.051663 -2.079455  1.123077
# 2024-01-03  0.697789 -0.262440  0.401806 -0.047228
# 2024-01-04  0.704163  0.648833  0.233249  0.479484
# 2024-01-05 -0.876755  2.044145  0.239583  1.373130
# 2024-01-06 -0.203976 -1.039639 -0.622584 -1.783899
#    2024-01-01  2024-01-02  2024-01-03  2024-01-04  2024-01-05  2024-01-06
# A   -0.754981    0.165291    0.697789    0.704163   -0.876755   -0.203976
# B    0.598583    1.051663   -0.262440    0.648833    2.044145   -1.039639
# C    1.168575   -2.079455    0.401806    0.233249    0.239583   -0.622584
# D    0.191978    1.123077   -0.047228    0.479484    1.373130   -1.783899

# %%
'''Sort DataFrame.'''
# Sort the DataFrame created in question 6 by the index (axis=1) in descending order.
# Sort the DataFrame created in question 6 by the values in column B.


df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)

dfSort = df.sort_index(axis=1, ascending=False)
print(dfSort)
# Out:
#                    A         B         C         D
# 2024-01-01 -0.187789  1.663943 -0.750624  0.924526
# 2024-01-02  1.567185  3.221622 -1.705059 -1.454071
# 2024-01-03 -0.414786 -1.980973 -0.987888 -0.539220
# 2024-01-04  1.476937 -1.455235 -0.978635 -0.218630
# 2024-01-05 -0.742515  0.030722  0.135489 -0.049669
# 2024-01-06  0.847860  1.022933 -0.051259 -1.384806
#                    D         C         B         A
# 2024-01-01  0.924526 -0.750624  1.663943 -0.187789
# 2024-01-02 -1.454071 -1.705059  3.221622  1.567185
# 2024-01-03 -0.539220 -0.987888 -1.980973 -0.414786
# 2024-01-04 -0.218630 -0.978635 -1.455235  1.476937
# 2024-01-05 -0.049669  0.135489  0.030722 -0.742515
# 2024-01-06 -1.384806 -0.051259  1.022933  0.847860

# %% [markdown]
# ## Part 4: Data Selection

# %%
''' Select Columns and Rows.'''
# Select the column A from the DataFrame created in question 6.



df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)

dfA= df['A']
print(dfA)
# Out:
#                    A         B         C         D
# 2024-01-01 -0.525441 -0.923152  0.689862  1.577906
# 2024-01-02 -1.527380 -1.023015  0.133203  1.585456
# 2024-01-03  0.465917 -0.576149  0.768960  0.094369
# 2024-01-04  1.091720 -1.244378  0.073591  0.543521
# 2024-01-05  0.334346  1.204097 -0.355627 -2.418262
# 2024-01-06  0.877384 -0.761954 -0.256897 -0.927887
# 2024-01-01   -0.525441
# 2024-01-02   -1.527380
# 2024-01-03    0.465917
# 2024-01-04    1.091720
# 2024-01-05    0.334346
# 2024-01-06    0.877384
# Freq: D, Name: A, dtype: float64

# %%
# Select the first 3 rows of the DataFrame created in question 6.

df.iloc[3]
# Out:
# A    1.091720
# B   -1.244378
# C    0.073591
# D    0.543521
# Name: 2024-01-04 00:00:00, dtype: float64

# %%
# Select the rows from "2024-01-02" to "2024-01-04" from the DataFrame created in question 6.
# Selection by Label.
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2024-01-01 -0.525441 -0.923152
# 2024-01-02 -1.527380 -1.023015
# 2024-01-03  0.465917 -0.576149
# 2024-01-04  1.091720 -1.244378
# 2024-01-05  0.334346  1.204097
# 2024-01-06  0.877384 -0.761954

# %%
# EXTRA FOR EXPERIMENT 

df.loc[(df["A"]< float(0.300000))]
# Out:
#                    A         B         C         D
# 2024-01-01 -0.525441 -0.923152  0.689862  1.577906
# 2024-01-02 -1.527380 -1.023015  0.133203  1.585456

# %%
# Select the data for the date "2024-01-02" from the DataFrame created in question 6.

df.loc[:, ["A"]]
# Out:
#                    A
# 2024-01-01 -0.525441
# 2024-01-02 -1.527380
# 2024-01-03  0.465917
# 2024-01-04  1.091720
# 2024-01-05  0.334346
# 2024-01-06  0.877384

# %%
# Select all rows for columns A and B from the DataFrame created in question 6.

df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2024-01-01 -0.525441 -0.923152
# 2024-01-02 -1.527380 -1.023015
# 2024-01-03  0.465917 -0.576149
# 2024-01-04  1.091720 -1.244378
# 2024-01-05  0.334346  1.204097
# 2024-01-06  0.877384 -0.761954

# %%
# Select rows from "2024-01-02" to "2024-01-04" for columns A and B from the DataFrame created in question 6.
# Selection by Position.
df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)

dfDates= df.loc ["20240102": "20240104", ["A", "B"]]
print(dfDates)
# Out:
#                    A         B         C         D
# 2024-01-01 -0.455206  1.807341  0.230125  0.704925
# 2024-01-02 -1.469412  2.010894  0.406324 -0.880151
# 2024-01-03  0.526302  0.793365  0.141810 -0.940410
# 2024-01-04 -0.722897  0.901970 -0.595050 -0.265488
# 2024-01-05 -0.705302 -0.243598 -0.342704 -1.764322
# 2024-01-06 -0.569597 -0.158850  0.320309 -0.116375
#                    A         B
# 2024-01-02 -1.469412  2.010894
# 2024-01-03  0.526302  0.793365
# 2024-01-04 -0.722897  0.901970

# %%
# Select the fourth row from the DataFrame created in question 6.
# Select rows 4 to 5 and columns 0 to 2 from the DataFrame created in question 6.
df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)

dfselect = df.loc["2024-01-04": "2024-01-05" ]
print(dfselect)
# Out:
#                    A         B         C         D
# 2024-01-01 -0.777711 -0.648654  0.437820 -1.896374
# 2024-01-02 -0.033581 -2.303452  1.810993 -0.976313
# 2024-01-03  0.195826 -0.204985  0.580955  0.741901
# 2024-01-04 -1.364665  0.890754  1.700434 -0.021467
# 2024-01-05  0.359184  0.553121 -1.354624 -0.884106
# 2024-01-06  0.775731 -1.339441  0.833974 -0.096791
#                    A         B         C         D
# 2024-01-04 -1.364665  0.890754  1.700434 -0.021467
# 2024-01-05  0.359184  0.553121 -1.354624 -0.884106

# %%
# Select the rows with positions 1, 2, and 4 and columns with positions 0 and 2 from the DataFrame created in question 6.

df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
print(df)
dfRow = df.loc[["A", "B" , "C" ] >" 2024-01-01 " :" 2024-01-02 " ]
print(dfRow)





# Select rows 2 to 3 from all columns in the DataFrame created in question 6.
# Select all rows and columns 2 to 3 from the DataFrame created in question 6.
# Out:
#                    A         B         C         D
# 2024-01-01  0.700941  0.451062 -0.829718 -0.714021
# 2024-01-02 -0.151789  1.661328 -0.683523 -0.727505
# 2024-01-03  2.874145 -2.092667  0.774268  0.257162
# 2024-01-04  0.701805  0.598222 -0.236418  1.075911
# 2024-01-05  0.953392 -0.953208  0.240020  0.234627
# 2024-01-06 -2.631941 -0.378712 -0.485212  0.162711
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 5
#       3 df= pd.DataFrame(np.random.randn(6,4),index=dates, columns=list("ABCD"))
#       4 print(df)
# ----> 5 dfRow = df.loc[["A", "B" , "C" ] >" 2024-01-01 " :" 2024-01-02 " ]
#       6 print(dfRow)
#      12 # Select rows 2 to 3 from all columns in the DataFrame created in question 6.
#      13 # Select all rows and columns 2 to 3 from the DataFrame created in question 6.
#
# ...
